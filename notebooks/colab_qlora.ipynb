# %% [markdown]
# # MedAI — Colab T4 backup notebook
#
# **Setup:** Runtime → Change runtime type → **T4 GPU** (free).
#
# Use this when Kaggle weekly quota (30 h) is exhausted or for fast iteration on small subsets.

# %%
# %%capture
# !pip install -q --upgrade pip
# !pip install -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install -q --no-deps "trl<0.9.0" peft accelerate bitsandbytes
# !pip install -q datasets pyyaml huggingface_hub

# %%
from google.colab import userdata
import os
os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(token=os.environ['HF_TOKEN'])

# !git clone https://github.com/vh0202/MedAI.git /content/MedAI
# %cd /content/MedAI

# %%
# Tokenizer test
# !python eval/tokenizer_test.py

# %%
# Prepare a SMALL subset for fast iteration on T4 (~5k samples)
# !python data/prepare_bilingual_mix.py --phase 1 --out data/colab_smoke.jsonl \
    --limit_en 3000 --limit_vi 1500

# %%
# Smoke train: 1 epoch, save_steps=100
# !python scripts/train_sft.py \
    --config configs/qwen25_7b_qlora.yaml \
    --data data/colab_smoke.jsonl
